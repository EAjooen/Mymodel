# %%
# !pip install tensorflow tensorflow-gpu opencv-python matplotlib
# Out:
# ...
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pip install --upgrade pip
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 13.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.1.2
#     Uninstalling pip-23.1.2:
#       Successfully uninstalled pip-23.1.2
# ...

# %%
pip install tensorflow-gpu==2.15.0
# Out:
# ERROR: Could not find a version that satisfies the requirement tensorflow-gpu==2.15.0 (from versions: 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0, 2.12.0)
# ERROR: No matching distribution found for tensorflow-gpu==2.15.0

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.9.5
# aiosignal                        1.3.1
# alabaster                        0.7.16
# albumentations                   1.3.1
# altair                           4.2.2
# annotated-types                  0.6.0
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array_record                     0.5.1
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# atpublic                         4.1.0
# attrs                            23.2.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.15.0
# ...

# %%
pip install opencv-python

# %%
import tensorflow as tf
import os

# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-837f90cc644e> in <cell line: 1>()
# ----> 1 drive.mount('/content/gdrive')
#
# NameError: name 'drive' is not defined

# %%
path = '/content/gdrive'

# %%
import cv2

image = cv2.imread('/content/gdrive/My Drive/Colab Notebooks/cat/cat1.jpg')

# %%
import os

# Now you can use 'os.path.join()' and other functions from the 'os' module
path = os.path.join('Colab Notebooks', 'cat')

# %%
gpus = tf.config.experimental.list_physical_devices('CPU')

# %%
gpus
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
  tf.config.experimental.set_memory_growth(gpu,True)

# %%
###Remove dodgy image

# %%
import cv2
import imghdr

# %%
data_dir = 'Colab Notebooks'

# %%
import os

# Assuming data_dir is defined somewhere earlier in your code
data_dir = 'Colab Notebooks'

# Joining directory paths and listing files
file_list = os.listdir(os.path.join(data_dir, 'cat'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-e6201b5f04f1> in <cell line: 7>()
#       5
#       6 # Joining directory paths and listing files
# ----> 7 file_list = os.listdir(os.path.join(data_dir, 'cat'))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Colab Notebooks/cat'

# %%
import os

data_dir = 'Colab Notebooks'

# Check if the directory exists
if os.path.exists(os.path.join(data_dir, 'cat')):
    # List files in the directory
    file_list = os.listdir(os.path.join(data_dir, 'cat'))
    print("Files in 'cat' directory:", file_list)
else:
    print("Directory 'cat' does not exist in the specified path.")
# Out:
# Directory 'cat' does not exist in the specified path.

# %%
os.listdir(os.path.join(data_dir,'cat')
# Out:
#   File "<ipython-input-23-14507ac4a9d9>", line 1
#     os.listdir(os.path.join(data_dir,'cat')
#                                            ^
# SyntaxError: incomplete input

# %%
image_exts = ['jpeg','jpg','bmp','png']

# %%
image_exts[1]
# Out:
# 'jpg'

# %%
image_exts[2]
# Out:
# 'bmp'
